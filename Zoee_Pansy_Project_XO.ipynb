# %%
import random
P1 = input("O ")
P2 = input("X ")
ran = print(random.randint(1 , 2))
if ran == 1:
  print(P1 + P2)
elif ran == 2:
  print(P2 + P1)
# Out:
# O Dede
# X 2
# 1

# %%
import random
PL = input()
PC = input()
i = random.randint(1 , 2)
print(i)
if i == 1:
  print("X" + " " + PL + " \nO" + " " + PC)
  PL = PL
  PC = PC
else:
  print("X" + " " + PC + " \nO"+ " " + PL)
  PC, PL = PL, PC
Box_1 = "1"
Box_2 = "2"
Box_3 = "3"
Box_4 = "4"
Box_5 = "5"
Box_6 = "6"
Box_7 = "7"
Box_8 = "8"
Box_9 = "9"
print("        "+ Box_1 +"           |         "+ Box_2 +"          |          " +Box_3 +"         ")
print("---------------------------------------------------------------")
print("        "+ Box_4 +"           |         "+ Box_5 +"          |          " +Box_6 +"         ")
print("---------------------------------------------------------------")
print("        "+ Box_7 +"           |         "+ Box_8 +"          |          " +Box_9 +"         ")

while True:

  while True: 
        player = input()

        if player == "1" and Box_1 != "X" and Box_1 != "O":
          Box_1 = "X"
          break
        elif player == "2" and Box_2 != "X" and Box_2 != "O":
          Box_2 = "X"
          break
        elif player == "3" and Box_3 != "X" and Box_3 != "O":
          Box_3 = "X"
          break
        elif player == "4" and Box_4 != "X" and Box_4 != "O":
          Box_4 = "X"
          break
        elif player == "5" and Box_5 != "X" and Box_5 != "O":
          Box_5 = "X" 
          break     
        elif player == "6" and Box_6 != "X" and Box_6 != "O":
          Box_6 = "X" 
          break 
        elif player == "7" and Box_7 != "X" and Box_7 != "O":
          Box_7 = "X"
          break    
        elif player == "8" and Box_8 != "X" and Box_8 != "O":
          Box_8 = "X"
          break  
        elif player == "9" and Box_9 != "X" and Box_9 != "O":
          Box_9 = "X"
          break
        else:
          print("ไม่สามารถเลือกช่องนี้ได้")      
  
  print("        "+ Box_1 +"           |         "+ Box_2 +"          |          " +Box_3 +"         ")
  print("---------------------------------------------------------------")
  print("        "+ Box_4 +"           |         "+ Box_5 +"          |          " +Box_6 +"         ")
  print("---------------------------------------------------------------")
  print("        "+ Box_7 +"           |         "+ Box_8 +"          |          " +Box_9 +"         ")  

  if Box_1 == Box_2 == Box_3 == "X":
    winner = PL
    break
  elif Box_4 == Box_5 == Box_6 == "X":
    winner = PL
    break    
  elif Box_7 == Box_8 == Box_9 == "X":
    winner = PL
    break
  elif Box_1 == Box_4 == Box_7 == "X":
    winner = PL
    break    
  elif Box_2 == Box_5 == Box_8 == "X":
    winner = PL
    break 
  elif Box_3 == Box_6 == Box_9 == "X":
    winner = PL
    break
  elif Box_3 == Box_5 == Box_7 == "X":
    winner = PL
    break 
  elif Box_1 == Box_5 == Box_9 == "X":
    winner = PL
    break
  if (Box_1 == "X" or Box_1 == "O") and \
     (Box_2 == "X" or Box_2 == "O") and \
     (Box_3 == "X" or Box_3 == "O") and \
     (Box_4 == "X" or Box_4 == "O") and \
     (Box_5 == "X" or Box_5 == "O") and \
     (Box_6 == "X" or Box_6 == "O") and \
     (Box_7 == "X" or Box_7 == "O") and \
     (Box_8 == "X" or Box_8 == "O") and \
     (Box_9 == "X" or Box_9 == "O"):
     winner = False
     break

  while True:
      player = input()
    
      if player == "1" and Box_1 != "X" and Box_1 != "O":
        Box_1 = "O"
        break
      elif player == "2" and Box_2 != "X" and Box_2 != "O":
        Box_2 = "O"
        break
      elif player == "3" and Box_3 != "X" and Box_3 != "O":
        Box_3 = "O"
        break
      elif player == "4" and Box_4 != "X" and Box_4 != "O":
        Box_4 = "O"
        break
      elif player == "5" and Box_5 != "X" and Box_5 != "O":
        Box_5 = "O"
        break      
      elif player == "6" and Box_6 != "X" and Box_6 != "O":
        Box_6 = "O"
        break  
      elif player == "7" and Box_7 != "X" and Box_7 != "O":
        Box_7 = "O"
        break    
      elif player == "8" and Box_8 != "X" and Box_8 != "O":
        Box_8 = "O"
        break  
      elif player == "9" and Box_9 != "X" and Box_9 != "O":
        Box_9 = "O"
        break  
      else:
        print("ไม่สามารถเลือกช่องนี้ได้") 
  
  print("        "+ Box_1 +"           |         "+ Box_2 +"          |          " +Box_3 +"         ")
  print("---------------------------------------------------------------")
  print("        "+ Box_4 +"           |         "+ Box_5 +"          |          " +Box_6 +"         ")
  print("---------------------------------------------------------------")
  print("        "+ Box_7 +"           |         "+ Box_8 +"          |          " +Box_9 +"         ")  
  if Box_1 == Box_2 == Box_3 == "O":
    winner = PC
    break
  elif Box_4 == Box_5 == Box_6 == "O":
    winner = PC
    break    
  elif Box_7 == Box_8 == Box_9 == "O":
    winner = PC
    break
  elif Box_1 == Box_4 == Box_7 == "O":
    winner = PC
    break    
  elif Box_2 == Box_5 == Box_8 == "O":
    winner = PC
    break 
  elif Box_3 == Box_6 == Box_9 == "O":
    winner = PC
    break
  elif Box_3 == Box_5 == Box_7 == "O":
    winner = PC
    break 
  elif Box_1 == Box_5 == Box_9 == "O":
    winner = PC
    break
  if (Box_1 == "X" or Box_1 == "O") and \
     (Box_2 == "X" or Box_2 == "O") and \
     (Box_3 == "X" or Box_3 == "O") and \
     (Box_4 == "X" or Box_4 == "O") and \
     (Box_5 == "X" or Box_5 == "O") and \
     (Box_6 == "X" or Box_6 == "O") and \
     (Box_7 == "X" or Box_7 == "O") and \
     (Box_8 == "X" or Box_8 == "O") and \
     (Box_9 == "X" or Box_9 == "O"):
     winner = False
     break

if winner == False:
  print("Tie")
else:
  print("Winner " + winner)
# Out:
# Dede
# baba
# 1
# X Dede
# O baba
#         1           |         2          |          3
# ---------------------------------------------------------------
#         4           |         5          |          6
# ---------------------------------------------------------------
#         7           |         8          |          9
# 4
#         1           |         2          |          3
# ---------------------------------------------------------------
#         X           |         5          |          6
# ---------------------------------------------------------------
#         7           |         8          |          9
# 5
#         1           |         2          |          3
# ---------------------------------------------------------------
#         X           |         O          |          6
# ---------------------------------------------------------------
#         7           |         8          |          9
# 6
# ...
